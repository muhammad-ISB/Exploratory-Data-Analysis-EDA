# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# standard scalea, normalization min max scala -> 0-1

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/proj/winequalityN.csv')
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
l_e = LabelEncoder()
df['type'] =  l_e.fit_transform(df['type'])
df
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.0             0.270         0.36            20.7
# 1        1            6.3             0.300         0.34             1.6
# 2        1            8.1             0.280         0.40             6.9
# 3        1            7.2             0.230         0.32             8.5
# 4        1            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6492     0            6.2             0.600         0.08             2.0
# 6493     0            5.9             0.550         0.10             2.2
# 6494     0            6.3             0.510         0.13             2.3
# 6495     0            5.9             0.645         0.12             2.0
# 6496     0            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.dropna()
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.0             0.270         0.36            20.7
# 1        1            6.3             0.300         0.34             1.6
# 2        1            8.1             0.280         0.40             6.9
# 3        1            7.2             0.230         0.32             8.5
# 4        1            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6491     0            6.8             0.620         0.08             1.9
# 6492     0            6.2             0.600         0.08             2.0
# 6494     0            6.3             0.510         0.13             2.3
# 6495     0            5.9             0.645         0.12             2.0
# 6496     0            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.dtypes
# Out:
# type                      int64
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# scaling

from sklearn.preprocessing import MinMaxScaler

scaling = MinMaxScaler()

scaling.fit_transform(df[1:]) # scaling everything other than our target / dependent variable - note every other column has just numerical features only = int/float hence i am doing it
# Out:
# array([[1.        , 0.20661157, 0.14666667, ..., 0.15168539, 0.2173913 ,
#         0.5       ],
#        [1.        , 0.3553719 , 0.13333333, ..., 0.12359551, 0.30434783,
#         0.5       ],
#        [1.        , 0.28099174, 0.1       , ..., 0.1011236 , 0.27536232,
#         0.5       ],
#        ...,
#        [0.        , 0.20661157, 0.28666667, ..., 0.29775281, 0.43478261,
#         0.5       ],
#        [0.        , 0.17355372, 0.37666667, ..., 0.2752809 , 0.31884058,
#         0.33333333],
#        [0.        , 0.18181818, 0.15333333, ..., 0.24719101, 0.43478261,
#         0.5       ]])

# %%
# z - score normalization

# will have the properties of standard normal distribution -> mean = 0 and standard deviation = 1
